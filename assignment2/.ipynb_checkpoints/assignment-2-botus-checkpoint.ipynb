# %%
import requests, time, re, random,hashlib
from bs4 import BeautifulSoup
import tweepy
from nltk import word_tokenize
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %% [markdown]
# ### Import the utilities here

# %%
import utilities

# %% [markdown]
# ### We will create a class called Company to hold all the information we have about each company

# %%
class Company(object):

    def __init__(self, name):
        self.name = name
        self.articles = None
        self.tweets = None
        self.articles_sentiments = None
        self.tweets_sentiments = None
        self.investment = None
        
    def __str__(self):
        return str(self.__class__) + ": " + str(self.__dict__)

# %% [markdown]
# ### Now let's get some tweets

# %%
def get_tweets(company_name, n=10):
    
    '''Takes a company name, returns a list of words in the tweets DO NOT MODIFY THIS FUNCTION '''
    
    api = create_twitter_api()
    tweets = api.search(q=company_name,lang='en', show_user=True, count=n)
    tweet_words = get_tweets_bag_of_words(tweets)
    return tweet_words

# %%
def create_twitter_api():
    
    '''
        Creates a twitter api client wrapper
        create_twitter_api takes no parameters but creates and returns a twitter API wrapper
        that you can use to interact with Twitter. You will copy and paste your credentials obtained in
        the first step here. 
        
        TODO: ERASE THEM WHEN YOU TURN IN THE ASSIGNMENT.
    '''
    
    # Variables that contains the user credentials to access Twitter API 
    ACCESS_TOKEN = '18374056-dppeSHfEbmM9Fs9eDhqEoTN9UVEX8DBkdkZ2rs0ji'
    ACCESS_SECRET = 'vM9xxXKdRxwL4wRqYSEZo4I13kSKqC79sorzbeVDdW35b'
    CONSUMER_KEY = 'x83VcMHlmDUpN3QFfuc5I4WEp'
    CONSUMER_SECRET = 'dG5RE8tae3h0tbF2Lg4z4aQOaPH8b71zLVanKPqXmTKEjxaAmh'
    auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
    auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)
    api = tweepy.API(auth)
    
    return api

# %%
def get_tweets_bag_of_words(tweets):
    
    '''
        Takes the result returned from twitter search, returns a list of words in the tweets
        
        get_tweet_bag_of_words takes the tweet search results and returns a list of words. You
        will need to parse the tweet search results in order to get the twitter status texts, get rid of the
        hashtag and other punctuations, and find a list of words. See what’s being returned:
        https://developer.twitter.com/en/docs/tweets/search/api-reference/get-search-tweets
    '''
    
    words = []
    
    for tweet in tweets:
        print(tweet._json)
        words += tweet._json['text'].split(" ")
        print
        print
    return words

# %% [markdown]
# ### Now let's fetch some articles about this company

# %%
def get_article(company_name, n=3):
    
    '''
    DO NOT MODIFY THIS FUNCTION
    
    Take a company name, returns a list of words in articles associated with the company.'''
    
    results = get_search_results(company_name)
    articles = get_articles_from_search_results(results,n)
    articles_bag_of_words = get_articles_bag_of_words(articles)
    
    return articles_bag_of_words

# %%
def get_search_results(company_name):
    
    '''
    Return an html with search results for a given company.
    get_search_results takes the name of the company and returns the search result page of USA
    News Today of the company. Below are some search result links for different terms.
    
    In technical terms: observe the pattern, recreate your own search link, and use fetch
    function we imported to get the html content.
    https://www.usatoday.com/search/facebook/
    
    '''
    url = "https://www.usatoday.com/search/" + company_name + "/"
    result = utilities.fetch(url)
#     print(result)

    return result

# %%
def get_articles_from_search_results(results_html, n):
    
    '''
        Return a list of n article htmls for given search results html.
    
        get_articles_from_search_results takes the search result page, get all the links to the news
        articles, and opens n links (default to 3 articles: for testing we suggest you use a small number
        because you will get your results faster and you are not aggressively scraping content and
        risking getting banned). Not all links returned from the page will be links to articles, so your
        function should ensure the links selected are in fact articles from the company search. In
        technical terms: find all the links to articles on the page (<a> using BeautifulSoup), and
        use fetch function we imported to get the html content of each link, store the article
        htmls, return a list of html.
    '''
    
    domain = 'http://www.usatoday.com'
    articles = []
    
    soup = BeautifulSoup(results_html)
    links = []
    for link in soup.find_all('a', href=True):
        if link['href'][0:7] == '/story/':
            links.append(link['href'])
    
    for idx, link in enumerate(links):
        if idx + 1 > n:
            break
        else:
            articles.append(utilities.fetch(domain+link))
    
    # excludes any video, audio results
    # search result links are relevant links, convert them to absolute links by adding the domain

    return articles

# %%
def get_articles_bag_of_words(articles):
    
    '''
        Return a list of words from a list of article htmls.
        
        get_articles_bag_of_words(articles) takes the html from the articles and return a list of words. In
        technical terms: for each article, find all the texts on the page (<p> using BeautifulSoup),
        extract words, clean words, return a list of words.
    
    '''
    
    bag_of_words = []
    for article in articles:
        # extract words from html and append to bag of words here
        soup = BeautifulSoup(article)
        for idx, para in enumerate(soup.find_all('p')):
            #             print(para.text)
            #             print(para.text.split(" "))
            for word in para.text.split(" "):
                if word[0:4] == 'http':
                    continue
                if word[-2:-1] == ':':
                    continue
                if word.isalpha():
                    bag_of_words.append(word)

    return bag_of_words

# %%
def get_sentiment(words):
    
    '''
    DO NOT MODIFY THIS FUNCTION
    
    Takes a list of words and returns a sentimental score. 
    
    '''
    
    analyzer = SentimentIntensityAnalyzer()
    total_compound = 0
    
    for w in words:
        score = analyzer.polarity_scores(w)
        total_compound += score['compound']
        
    return total_compound

# %%
def get_decision(tweets_sentiments, articles_sentiments):
    
    '''
    DO NOT MODIFY THIS FUNCTION
    
    Takes two sentimental scores from tweets and articles and return a final financial decision. 
    Invest if total sentiment is positive. 
    
    '''
    
    return (tweets_sentiments + articles_sentiments > 0)

# %% [markdown]
# ### Results

# %%
company = Company('facebook')

# %%
company.tweets = get_tweets('facebook', 200)
# Out:
# {'created_at': 'Fri Nov 10 14:52:54 +0000 2017', 'id': 928998907862011904, 'id_str': '928998907862011904', 'text': 'RT @HeymanHustle: . @BrockLesnar vs @AJStylesOrg \n@WWE #SurvivorSeries \n#ChampionvsChampion \nMeanwhile, over on #Facebook - https://t.co/n2…', 'truncated': False, 'entities': {'hashtags': [{'text': 'SurvivorSeries', 'indices': [55, 70]}, {'text': 'ChampionvsChampion', 'indices': [72, 91]}, {'text': 'Facebook', 'indices': [112, 121]}], 'symbols': [], 'user_mentions': [{'screen_name': 'HeymanHustle', 'name': 'Paul Heyman', 'id': 23089228, 'id_str': '23089228', 'indices': [3, 16]}, {'screen_name': 'BrockLesnar', 'name': 'Brock Lesnar', 'id': 1222616833, 'id_str': '1222616833', 'indices': [20, 32]}, {'screen_name': 'AJStylesOrg', 'name': 'AJStyles.Org', 'id': 43769311, 'id_str': '43769311', 'indices': [36, 48]}, {'screen_name': 'WWE', 'name': 'WWE', 'id': 7517222, 'id_str': '7517222', 'indices': [50, 54]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id':
 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 54, 'friends_count': 447, 'listed_count': 1, 'created_at': 'Tue Feb 07 09:57:50 +0000 2017', 'favourites_count': 138, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 335, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/828923366543413248/ikLFLnY1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/828923366543413248/ikLFLnY1_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/828905600583073792/1510128469', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}
# {'created_at': 'Fri Nov 10 14:52:52 +0000 2017', 'id': 928998902400925696, 'id_str': '928998902400925696', 'text': "RT @froozer: Looking for some new #recipes for #thanksgiving?! We've got a treat for you! Click here to see the full recipe: https://t.co/O…", 'truncated': False, 'entities': {'hashtags': [{'text': 'recipes', 'indices': [34, 42]}, {'text': 'thanksgiving', 'indices': [47, 60]}], 'symbols': [], 'user_mentions': [{'screen_name': 'froozer', 'name': 'Froozer®', 'id': 2975166589, 'id_str': '2975166589', 'indices': [3, 11]}], 'urls': []}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 210207996, 'id_str': '210207996', 'name': 'ColoradoSoccer', 'screen_name': 'wearecosoccer', 'location': 'Colorado', 'description': '', 'url': 'http://t.co/XNB0MLs4fF', 'entities': {'url': {'urls': [{'url': 'http://t.co/XNB0MLs4fF', 'expanded_url': 'http://www.coloradosoccer.org', 'display_url': 'coloradosoccer.org', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 2579, 'friends_count': 1235, 'listed_count': 43, 'created_at': 'Sat Oct 30 21:03:06 +0000 2010', 'favourites_count': 1770, 'utc_offset': -25200, 'time_zone': 'Mountain Time (US & Canada)', 'geo_enabled': True, 'verified': False, 'statuses_count': 12036, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '709397', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/474220552006021121/EHqnzERB.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/474220552006021121/EHqnzERB.jpeg', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/872180571178389504/7aiGXlmG_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/872180571178389504/7aiGXlmG_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/210207996/1496778634', 'profile_link_color': 'FF3300', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'A0C5C7', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Nov 10 14:05:09 +0000 2017', 'id': 928986890711306246, 'id_str': '928986890711306246', 'text': "Looking for some new #recipes for #thanksgiving?! We've got a treat for you! Click here to see the full recipe:… https://t.co/r3X5kZZ0VA", 'truncated': True, 'entities': {'hashtags': [{'text': 'recipes', 'indices': [21, 29]}, {'text': 'thanksgiving', 'indices': [34, 47]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/r3X5kZZ0VA', 'expanded_url': 'https://twitter.com/i/web/status/928986890711306246', 'display_url': 'twitter.com/i/web/status/9…', 'indices': [113, 136]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://bufferapp.com" rel="nofollow">Buffer</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 2975166589, 'id_str': '2975166589', 'name': 'Froozer®', 'screen_name': 'froozer', 'location': 'Denver, CO', 'description': 'Frozen fruit & veggie snack. Non-GMO, vegan, no added sugar, kosher, gluten-free, dairy-free. Simple ingredients. Real nutrition.®', 'url': 'https://t.co/2W4CSkABvG', 'entities': {'url': {'urls': [{'url': 'https://t.co/2W4CSkABvG',  ...
# {'created_at': 'Fri Nov 10 14:52:52 +0000 2017', 'id': 928998901423755264, 'id_str': '928998901423755264', 'text': 'I Swear! https://t.co/hXi93f6Kg4', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/hXi93f6Kg4', 'expanded_url': 'http://fb.me/5L1TA1WFM', 'display_url': 'fb.me/5L1TA1WFM', 'indices': [9, 32]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id':
normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/18281751/1499609869', 'profile_link_color': '4A913C', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '05FFFB', 'profile_text_color': '3E4415', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'retweeted_status': {'created_at': 'Fri Nov 10 14:50:32 +0000 2017', 'id': 928998313080143872, 'id_str': '928998313080143872', 'text': 'Retweeted Judd Apatow (@JuddApatow):\n\nEveryone must retweet this!  This is what Trump is about— ignorance and... https://t.co/WrzM3nQ8GJ', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'JuddApatow', 'name': 'Judd Apatow', 'id': 88749392, 'id_str': '88749392', 'indices': [23, 34]}], 'urls': [{'url': 'https://t.co/WrzM3nQ8GJ', 'expanded_url': 'http://fb.me/3cPjp0Rcb', 'display_url': 'fb.me/3cPjp0Rcb', 'indices': [113, 136]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3148736402, 'id_str': '3148736402', 'name': 'Rosanna Arquette', 'screen_name': 'RoArquette', 'location': 'Los Angeles, CA', 'description': 'Official Twitter for Rosanna Arquette, director, actor, producer and activist', 'url': 'https:// ...
# {'created_at': 'Fri Nov 10 14:52:43 +0000 2017', 'id': 928998862982991872, 'id_str': '928998862982991872', 'text': 'Leela just worked out how much fun it is to eat her pod 🙊 😂 at least she is having fun 😉 #chinchilla https://t.co/feV3Wm0Kf9', 'truncated': False, 'entities': {'hashtags': [{'text': 'chinchilla', 'indices': [89, 100]}], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/feV3Wm0Kf9', 'expanded_url': 'http://fb.me/Mr9p68MK', 'display_url': 'fb.me/Mr9p68MK', 'indices': [101, 124]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 3255453483, 'id_str': '3255453483', 'name': 'Cat FurNature', 'screen_name': 'CatFurNature', 'location': 'UK', 'description': 'Our mission is to make happy cats! Take a look at our environmentally friendly awesome products', 'url': 'https://t.co/T2Snq0kCLl', 'entities': {'url': {'urls': [{'url': 'https://t.co/T2Snq0kCLl', 'expanded_url': 'http://www.catfurnature.co.uk', 'display_url': 'catfurnature.co.uk', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 986, 'friends_count': 1228, 'listed_count': 33, 'created_at': 'Fri May 15 06:40:56 +0000 2015', 'favourites_count': 1039, 'utc_offset': None, 'time_zone': None, 'geo_enabled': True, 'verified': False, 'statuses_count': 29053, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/685752277316026368/_4REyC9P_normal.png', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/685752277316026368/_4REyC9P_normal.png', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3255453483/1452332205', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}
# {'created_at': 'Fri Nov 10 14:52:43 +0000 2017', 'id': 928998862903283712, 'id_str': '928998862903283712', 'text': "I find it difficult to survive through a month or week without this type of food. \n\nSincerely, if you're close... https://t.co/XYgjjIRSVP", 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/XYgjjIRSVP', 'expanded_url': 'http://fb.me/99936qlLl', 'display_url': 'fb.me/99936qlLl', 'indices': [114, 137]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 507560739, 'id_str': '507560739', 'name': 'MaChinoLar Company', 'screen_name': 'preciousojewusi', 'location': 'Lagos Nigeria', 'description': 'love Jesus Christ above all', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 156, 'friends_count': 365, 'listed_count': 1, 'created_at': 'Tue Feb 28 16:04:35 +0000 2012', 'favourites_count': 120, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 1614, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/911704533713252352/koeVMNEW_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/911704533713252352/koeVMNEW_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/507560739/1364836129', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}
# {'created_at': 'Fri Nov 10 14:52:43 +0000 2017', 'id': 928998862827569154, 'id_str': '928998862827569154', 'text': 'I posted a new video to Facebook https://t.co/gGUvtWVmIA', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [{'url': 'https://t.co/gGUvtWVmIA', 'expanded_url': 'http://fb.me/6oVVk4ztX', 'display_url': 'fb.me/6oVVk4ztX', 'indices': [33, 56]}]}, 'metadata': {'iso_language_code': 'en', 'result_type': 'recent'}, 'source': '<a href="http://www.facebook.com/twitter" rel="nofollow">Facebook</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 101559009, 'id_str': '101559009', 'name': 'Dev Bhagtani', 'screen_name': 'iamdpb', 'location': 'Mumbai ', 'description': 'Actor by Profession.', 'url': 'https://t.co/8wiONIaxfh', 'entities': {'url': {'urls': [{'url': 'https://t.co/8wiONIaxfh', 'expanded_url': 'http://www.facebook.com/dipesh.bhagtani', 'display_url': 'facebook.com/dipesh.bhagtani', 'indices': [0, 23]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 147, 'friends_count': 80, 'listed_count': 1, 'created_at': 'Sun Jan 03 19:58:54 +0000 2010', 'favourites_count': 60, 'utc_offset': 19800, 'time_zone': 'Mumbai', 'geo_enabled': True, 'verified': False, 'statuses_count': 1412, 'lang': 'en', 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'DBE9ED', 'profile_background_image_url': 'http://pbs.twimg.com/profile_background_images/678595481/d29e313fdffd9d03b7793fbe185f76c0.jpeg', 'profile_background_image_url_https': 'https://pbs.twimg.com/profile_background_images/678595481/d29e313fdffd9d03b7793fbe185f76c0.jpeg', 'profile_background_tile': True, 'profile_image_url': 'http://pbs.twimg.com/profile_images/544200070745186304/W_Q3TGum_normal.jpeg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/544200070745186304/W_Q3TGum_normal.jpeg', 'profile_link_color': 'CC3366', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': '99CC33', 'profile_text_color': '3E4415', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'en'}

# %%
company.articles = get_article('facebook', 3)
# Out:
# Retrieving from cache: https://www.usatoday.com/search/facebook/
# Retrieving from cache: http://www.usatoday.com/story/news/2013/01/09/corrections-clarifications/1821023/
# Retrieving from cache: http://www.usatoday.com/story/news/2013/01/09/corrections-clarifications/1821023/
# Retrieving from cache: http://www.usatoday.com/story/tech/2017/11/09/facebook-friends-small-businesses-facebook-community-boost/847094001/
# /usr/local/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/local/Cellar/python3/3.6.3/Frameworks/Python.framework/Versions/3.6/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))

# %%
company.tweets_sentiments = get_sentiment(company.tweets)

# %%
company.articles_sentiments = get_sentiment(company.articles)

# %%
company.investment = get_decision(company.tweets_sentiments, company.articles_sentiments)

# %%
print(company)
# Out:
# <class '__main__.Company'>: {'name': 'facebook', 'articles': ['Settings', 'Cancel', 'Set', 'Hi', 'Already', 'a', 'Subscribe', 'to', 'USA', 'TODAY', 'Already', 'a', 'print', 'edition', 'but', 'have', 'a', 'Manage', 'your', 'account', 'Support', 'Log', 'Out', 'Get', 'the', 'news', 'Let', 'friends', 'in', 'your', 'social', 'network', 'know', 'what', 'you', 'are', 'reading', 'about', 'The', 'following', 'corrections', 'and', 'clarifications', 'have', 'been', 'published', 'by', 'USA', 'A', 'link', 'has', 'been', 'posted', 'to', 'your', 'Facebook', 'To', 'report', 'corrections', 'contact', 'USA', 'TODAY', 'Network', 'Standards', 'Editor', 'Brent', 'Please', 'indicate', 'whether', 'responding', 'to', 'content', 'online', 'or', 'in', 'the', 'The', 'following', 'corrections', 'clarifications', 'have', 'been', 'published', 'on', 'stories', 'produced', 'by', 'USA', 'November', 'item', 'in', 'the', 'Michigan', 'section', 'of', 'the', 'page', 'mistakenly', 'contained', 'information', 'about', 'a', 'shipping', 'hopes', 'to', 'launch', 'flying', 'car', 'service', 'by', 'A', 'previous', 'version', 'of', 'this', 'video', 'incorrectly', 'stated', 'the', 'capabilities', 'of', 'flying', 'previous', 'version', 'of', 'this', 'story', 'erroneously', 'included', 'a', 'mass', 'shooting', 'in', 'Oregon', 'in', 'which', 'the', 'gunman', 'did', 'not', 'use', 'an', 'video', 'on', 'a', 'rescued', 'baby', 'beluga', 'calf', 'misstated', 'the', 'amount', 'of', 'beluga', 'whales', 'left', 'in', 'the', 'There', 'are', 'only', 'Cook', 'Inlet', 'beluga', 'whales', 'left', 'in', 'the', 'There', 'are', 'other', 'populations', 'of', 'beluga', 'whales', 'found', 'in', 'the', 'the', 'World', 'Series', 'included', 'the', 'incorrect', 'year', 'for', 'when', 'Cleveland', 'last', 'won', 'the', 'World', 'Series', 'and', 'left', 'out', 'a', 'team', 'among', 'those', 'who', 'have', 'never', 'won', 'the', 'The', 'Indians', 'won', 'in', 'and', 'the', 'Brewers', 'are', 'among', 'those', 'who', 'have', 'never', 'story', 'about', 'proposed', 'tax', 'changes', 'for', 'Americans', 'misstated', 'the', 'effective', 'date', 'for', 'The', 'proposed', 'changes', 'would', 'take', 'effect', 'after', 'Social', 'Instagram', 'post', 'on', 'on', 'used', 'the', 'wrong', 'photo', 'with', 'a', 'quote', 'from', 'the', 'Houston', 'Carlos', 'The', 'post', 'was', 'Your', 'previous', 'version', 'of', 'this', 'letter', 'to', 'the', 'Kevin', 'It', 'is', 'now', 'labeled', 'as', 'previous', 'version', 'of', 'this', 'story', 'included', 'an', 'for', 'the', 'Bill', 'Mazeroski', 'in', 'the', 'World', 'item', 'in', 'Sportsline', 'incorrectly', 'referred', 'to', 'Jerry', 'Jones', 'of', 'the', 'Dallas', 'He', 'is', 'the', 'previous', 'version', 'of', 'this', 'story', 'included', 'an', 'incorrect', 'nickname', 'for', 'Don', 'previous', 'version', 'of', 'this', 'story', 'incorrectly', 'referred', 'to', 'Martinsville', 'as', 'the', 'oldest', 'track', 'on', 'the', 'NASCAR', 'earlier', 'version', 'of', 'the', 'story', 'mischaracterized', 'the', 'Edison', 'Electric', 'The', 'story', 'also', 'misstated', 'the', 'payment', 'status', 'of', 'workers', 'from', 'Jacksonville', 'Electric', 'Authority', 'for', 'work', 'story', 'on', 'changes', 'in', 'Mega', 'Millions', 'lottery', 'game', 'on', 'left', 'out', 'several', 'states', 'and', 'the', 'District', 'of', 'Columbia', 'that', 'initially', 'are', 'offering', 'the', 'Just', 'the', 'Jackpot', 'option', 'at', 'its', 'inception', 'that', 'happened', 'The', 'states', 'total', 'are', 'New', 'New', 'New', 'Rhode', 'South', 'South', 'West', 'Virginia', 'and', 'login', 'Protected', 'is', 'built', 'into', 'the', 'Android', 'operating', 'previous', 'version', 'of', 'this', 'article', 'misstated', 'the', 'date', 'of', 'Rodrigo', 'earlier', 'version', 'of', 'the', 'headline', 'accompanying', 'this', 'story', 'misstated', 'the', 'poll', 'editorial', 'has', 'been', 'updated', 'to', 'reflect', 'the', 'fact', 'that', 'not', 'all', 'of', 'the', 'soldiers', 'killed', 'in', 'Niger', 'were', ...
